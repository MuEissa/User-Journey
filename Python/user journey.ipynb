# %%
import pandas as pd
import numpy as np

# %%
url = r"C:\MY WORLD\Projects\User Journey analysis\SQL\user journey.csv"
raw_data = pd.read_csv(url)

# %% [markdown]
# ## Data Cleaning

# %%
raw_data.head()
# Out:
#    user_id  session_id  first_purchase_date subscription_type  \
# 0     1516     2980231  2023-01-27 12:16:44           Annualy
# 1     1516     2980248  2023-01-27 12:16:44           Annualy
# 2     1516     2992252  2023-01-27 12:16:44           Annualy
# 3     1516     3070491  2023-01-27 12:16:44           Annualy
# 4     1516     3709807  2023-01-27 12:16:44           Annualy
#
#             event_date                                       user_journey
# 0  2022-12-11 17:42:46  Log in-Other-Log in-Log in-Log in-Log in-Log i...
# 1  2022-12-11 17:44:57  Log in-Log in-Log in-Log in-Log in-Log in-Sign...
# 2  2022-12-12 13:22:59          Log in-Log in-Log in-Log in-Log in-Log in
# 3  2022-12-15 08:24:45  Log in-Log in-Log in-Log in-Log in-Log in-Log ...
# 4  2023-01-26 07:58:16  Log in-Log in-Log in-Log in-Log in-Log in-Log ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6876 entries, 0 to 6875
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              6876 non-null   int64
#  1   session_id           6876 non-null   int64
#  2   first_purchase_date  6876 non-null   object
#  3   subscription_type    6876 non-null   object
#  4   event_date           6876 non-null   object
#  5   user_journey         6876 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 322.4+ KB

# %%
#Creating a copy of the raw data frame, which is to be modified, avoiding corrupting the original source of data. 
#Columns deleted are of no use for the analysis given the kinda narrow scope of the provided data

clean = raw_data.copy().drop(['session_id', 'first_purchase_date', 'event_date'], axis=1)

# %%
clean.head()
# Out:
#    user_id subscription_type  \
# 0     1516           Annualy
# 1     1516           Annualy
# 2     1516           Annualy
# 3     1516           Annualy
# 4     1516           Annualy
#
#                                         user_journey
# 0  Log in-Other-Log in-Log in-Log in-Log in-Log i...
# 1  Log in-Log in-Log in-Log in-Log in-Log in-Sign...
# 2          Log in-Log in-Log in-Log in-Log in-Log in
# 3  Log in-Log in-Log in-Log in-Log in-Log in-Log ...
# 4  Log in-Log in-Log in-Log in-Log in-Log in-Log ...

# %%
clean = clean.groupby(['user_id', 'subscription_type'])['user_journey'].agg(lambda x: '-'.join(x)).reset_index()
clean
# Out:
#       user_id subscription_type  \
# 0        1516           Annualy
# 1        3395           Annualy
# 2       10107           Annualy
# 3       11145           Monthly
# 4       12400           Monthly
# ...       ...               ...
# 1204   508638           Annualy
# 1205   508647           Annualy
# 1206   508649           Monthly
# 1207   508655           Annualy
# 1208   508670           Annualy
#
#                                            user_journey
# 0     Log in-Other-Log in-Log in-Log in-Log in-Log i...
# 1     Log in-Log in-Sign up-Log in-Pricing-Sign up-H...
# 2     Resource center-Other-Resource center-Resource...
# 3     Log in-Log in-Homepage-Log in-Log in-Log in-Lo...
# 4     Log in-Log in-Log in-Log in-Sign up-Log in-Car...
# ...                                                 ...
# 1204  Other-Other-Coupon-Coupon-Coupon-Coupon-Coupon...
# 1205  Course certificate-Pricing-Course certificate-...
# 1206  Other-Other-Other-Other-Other-Other-Other-Othe...
# 1207  Courses-Courses-Courses-Courses-Career tracks-...
# 1208  Log in-Log in-Log in-Log in-Log in-Log in-Log ...
#
# [1209 rows x 3 columns]

# %%
def remove_duplicates(string):
    pages = string.split('-')
    i = 0
    while i < len(pages)-1:
        if pages[i] == pages[i+1]: 
            pages.pop(i)
        else:
            i += 1
    string = '-'.join(pages)
    return string

# %%
clean['user_journey'] = clean['user_journey'].apply(remove_duplicates)

# %%
clean.head()
# Out:
#    user_id subscription_type  \
# 0     1516           Annualy
# 1     3395           Annualy
# 2    10107           Annualy
# 3    11145           Monthly
# 4    12400           Monthly
#
#                                         user_journey
# 0  Log in-Other-Log in-Homepage-Log in-Sign up-Ot...
# 1  Log in-Sign up-Log in-Pricing-Sign up-Homepage...
# 2  Resource center-Other-Resource center-Homepage...
# 3  Log in-Homepage-Log in-Homepage-Log in-Homepag...
# 4  Log in-Sign up-Log in-Career tracks-Sign up-Ca...

# %%
clean.to_csv('cleaned data.csv')

# %% [markdown]
# ## Data Analysis

# %%
def page_count(df):
    user_journey = np.array(df)
        #splitting pages
    for i in range(len(user_journey)):
        user_journey[i] = np.array(user_journey[i].split('-'))
        #creating a dictionary, with a record representing each page in user journeys
    results = {}
    results['Total pages'] = 0
    for journey in user_journey:
        for page in journey: 
            #the line retrieves the record for the page if it is present already, and initializes one for it if not
            results[page] = results.get(page, 0) + 1 
            results['Total pages'] += 1 
    #sorting the dictionary by the page count
    results = dict(sorted(results.items(), key=lambda item: item[1]))
    return results

# %%
def page_presence (data):
    user_journey = np.array(data)
    
    #Splitting each user journey into a set of page. Unlike lists, sets will keep on only one occurence of each page in a journey
    for i in range(len(user_journey)):
        user_journey[i] = set(user_journey[i].split('-'))

    presence = {}
    presence['Total journeys'] = len(user_journey)

    for journey in user_journey:
        for page in journey: 
            presence[page] = presence.get(page, 0) + 1 

    #Sorting the dictionary by page occurences
    presence = dict(sorted(presence.items(), key= lambda item: item[1], reverse=True)) 

    return presence

# %%
def avg_journey_length (data):
    user_journey = np.array(data)
    
    #Splitting journeys into separate pages 
    for i in range(len(user_journey)):
        user_journey[i] = np.array(user_journey[i].split('-'))
    
    journey_lengths = np.zeros(len(user_journey))
    
    #Getting the length of each user journey
    for i in range(len(user_journey)):
        journey_lengths[i] = len(user_journey[i])
    
    #Calculating the average journey length 
    journey_avg_length = np.sum(journey_lengths) / len(journey_lengths)

    return journey_avg_length

# %%
def page_sequence (data, number_of_pages=3):
    # data is the series to get checked for sequences
    # n is the number of pages to check for as its occurence a sequence
    user_journey = np.array(data)

    #Splitting journeys into separate pages 
    for i in range(len(user_journey)):
        user_journey[i] = np.array(user_journey[i].split('-'))

    sequences = {}
    for journey in user_journey: 
        flag = {}                                  #For each user journey, if a page sequence is already captured, the flag is there to ignore it
        for i in range(len(journey) - number_of_pages + 1 ): 
            page_sequence = tuple(journey[i : i + number_of_pages])
              #If the sequence is already present in the journey, skip the current iteration
            if flag.get(page_sequence, False): continue
            sequences[page_sequence] = sequences.get(page_sequence, 0) + 1
            flag[page_sequence] = True

    sequences = dict(sorted(sequences.items(), key= lambda item: item[1], reverse=True))
    return sequences

# %%
def page_destinations(data): 
    #Splitting journeys into separate pages 
    user_journey = [journey.split('-') for journey in np.array(data)]

    #Obtaining a unique set of the pages
    page_set = set()
    for journey in user_journey: 
        page_set.update(journey) 
    
    #Constructing a dictionary of dictionaries, where each key represent a page
    destinations = {key: dict() for key in page_set}

    #For each page in the dictionary, we count how many times it was the source for all other pages
    for journey in user_journey: 
        for i in range(len(journey)-1):
            source_page = journey[i]
            destination_page = journey[i+1]
            destinations[source_page][destination_page] = destinations[source_page].get(destination_page, 0) + 1 
    
    for key, page in destinations.items():
        destinations[key] = dict(sorted(page.items(), key = lambda item: item[1], reverse = True))
    
    return destinations

# %%
def limit(data, limit=10):
    # Function limits the number of records returned from a dictionary
    keys = sorted(data, key=data.get, reverse= True)[:limit]
    limited = {key: sequences[key] for key in keys}
    return limited

# %% [markdown]
# #### The frequency of pages

# %%
page_count = page_count(clean['user_journey'])
page_count
# Out:
# {'Blog': 25,
#  'About us': 28,
#  'Instructors': 53,
#  'Success stories': 84,
#  'Course certificate': 399,
#  'Coupon': 619,
#  'Resource center': 661,
#  'Career track certificate': 810,
#  'Other': 1010,
#  'Checkout': 1280,
#  'Pricing': 1369,
#  'Sign up': 1568,
#  'Career tracks': 1614,
#  'Courses': 1654,
#  'Log in': 2026,
#  'Homepage': 2072,
#  'Total pages': 15272}

# %% [markdown]
# #### How often a page contributes to a journey?

# %%
presence = page_presence(clean['user_journey'])
presence
# Out:
# {'Total journeys': 1209,
#  'Checkout': 752,
#  'Homepage': 725,
#  'Log in': 655,
#  'Sign up': 604,
#  'Coupon': 531,
#  'Other': 412,
#  'Pricing': 402,
#  'Courses': 371,
#  'Career tracks': 306,
#  'Career track certificate': 181,
#  'Resource center': 146,
#  'Course certificate': 118,
#  'Success stories': 27,
#  'Instructors': 25,
#  'About us': 15,
#  'Blog': 11}

# %% [markdown]
# #### Average length of journey

# %%
average_length = avg_journey_length(clean['user_journey'])
average_length
# Out:
# 12.631927212572373

# %% [markdown]
# #### Popular page sequences?

# %%
sequences = page_sequence(clean.user_journey)
limit(sequences)
# Out:
# {('Log in', 'Homepage', 'Log in'): 305,
#  ('Homepage', 'Log in', 'Checkout'): 222,
#  ('Sign up', 'Homepage', 'Sign up'): 154,
#  ('Career tracks', 'Courses', 'Career tracks'): 137,
#  ('Career tracks', 'Homepage', 'Career tracks'): 134,
#  ('Courses', 'Homepage', 'Courses'): 123,
#  ('Courses', 'Career tracks', 'Courses'): 119,
#  ('Log in', 'Sign up', 'Log in'): 111,
#  ('Sign up', 'Courses', 'Sign up'): 106,
#  ('Homepage', 'Log in', 'Homepage'): 105}

# %% [markdown]
# #### Page follow-ups

# %%
destination = pd.DataFrame(page_destinations(clean['user_journey']))
destination
# Out:
#                           Resource center  Sign up  Instructors  Log in  Blog  \
# Other                               335.0     45.0          4.0   149.0   9.0
# Pricing                              52.0    125.0          5.0    82.0   3.0
# Courses                              49.0    235.0          7.0    93.0   3.0
# Homepage                             46.0    268.0         20.0   608.0   1.0
# Log in                               37.0    357.0          3.0     NaN   2.0
# Career track certificate             35.0     59.0          5.0    28.0   NaN
# Career tracks                        34.0    195.0          1.0    57.0   2.0
# Course certificate                   27.0     28.0          1.0    11.0   NaN
# Sign up                              14.0      NaN          1.0   254.0   NaN
# Success stories                       9.0      2.0          NaN     7.0   1.0
# Coupon                                7.0     42.0          1.0   107.0   1.0
# Checkout                              7.0    175.0          1.0   563.0   1.0
# About us                              3.0      1.0          3.0     NaN   NaN
# Blog                                  3.0      NaN          NaN     2.0   NaN
# Instructors                           2.0      1.0          NaN     3.0   NaN
# Resource center                       NaN     23.0          NaN    34.0   2.0
#
#                           Other  Career track certificate  Coupon  \
# Other                       NaN                      31.0    20.0
# Pricing                    58.0                     102.0     5.0
# Courses                    80.0                     100.0     5.0
# Homepage                   42.0                     108.0    14.0
# Log in                    163.0                      29.0    65.0
# Career track certificate   34.0                       NaN     4.0
# Career tracks              53.0                     200.0     5.0
# Course certificate         32.0                      83.0     NaN
# Sign up                    48.0                      79.0    19.0
# Success stories            22.0                      10.0     1.0
# Coupon                     48.0                      12.0     NaN
# Checkout                   34.0                      13.0    54.0
# About us                    6.0                       2.0     NaN
# Blog                        6.0                       1.0     NaN
# Instructors                 2.0                       5.0     1.0
# Resource center           309.0                      32.0     3.0
#
#                           Success stories  About us  Courses  Pricing  \
# Other                                20.0       5.0     79.0     44.0
# Pricing                               6.0       2.0    193.0      NaN
# Courses                               5.0       2.0      NaN    184.0
# Homepage                              6.0       3.0    235.0    187.0
# Log in                                3.0       1.0    102.0    139.0
# Career track certificate              8.0       2.0     89.0     94.0
# Career tracks                        12.0       NaN    529.0    120.0
# Course certificate                    NaN       NaN     70.0     36.0
# Sign up                               4.0       2.0    212.0    134.0
# Success stories                       NaN       2.0      4.0      7.0
# Coupon                                2.0       NaN     30.0     49.0
# Checkout                              4.0       2.0     41.0    304.0
# About us                              2.0       NaN      2.0      1.0
# Blog                                  1.0       NaN      3.0      2.0
# Instructors                           NaN       3.0     10.0      1.0
# Resource center                      10.0       3.0     53.0     51.0
#
#                           Homepage  Career tracks  Checkout  \
# Other                         32.0           55.0      27.0
# Pricing                      374.0          130.0     152.0
# Courses                      232.0          481.0      23.0
# Homepage                       NaN          312.0     112.0
# Log in                       605.0           73.0     196.0
# Career track certificate     104.0          234.0       7.0
# Career tracks                297.0            NaN      25.0
# Course certificate            52.0           40.0       3.0
# Sign up                      278.0          177.0      25.0
# Success stories                4.0           12.0       1.0
# Coupon                         6.0           29.0      57.0
# Checkout                      13.0           25.0       NaN
# About us                       4.0            1.0       2.0
# Blog                           4.0            NaN       NaN
# Instructors                   22.0            2.0       NaN
# Resource center               43.0           37.0      10.0
#
#                           Course certificate
# Other                                   31.0
# Pricing                                 34.0
# Courses                                 64.0
# Homepage                                55.0
# Log in                                  20.0
# Career track certificate                82.0
# Career tracks                           31.0
# Course certificate                       NaN
# Sign up                                 34.0
# Success stories                          NaN
# Coupon                                  11.0
# Checkout                                10.0
# About us                                 NaN
# Blog                                     NaN
# Instructors                              1.0
# Resource center                         26.0
